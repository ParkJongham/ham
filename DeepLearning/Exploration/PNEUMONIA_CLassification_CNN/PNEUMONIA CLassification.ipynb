# %%
# 1

import re    
import os    
import pandas as pd     
import numpy as np     
import tensorflow as tf  
import matplotlib.pyplot as plt    
from sklearn.model_selection import train_test_split

# %%
# 2

# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'))

# BATCH_SIZE 변수
BATCH_SIZE = 32

# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# EPOCH 크기 변수
EPOCHS = 25

# %%
# 3

train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*'))

# %%
# 4

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %%
# 5

filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*')))

# train, test(val) dataset으로 분할. test_size에 0.2는 20%롤 의미함.
train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
# 6

COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1086
# Pneumonia images count in training set: 3099

# %%
# 7

train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
# 8

TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 9

# 라벨 이름이 폴더이기 때문에 경로상의 마지막을 추출한다.
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/chest_xray/train/*"))])
print(CLASS_NAMES)
# Out:
# ['PNEUMONIA' 'NORMAL']

# %%
# 10

def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)   # os.path.sep : 파일 각 경로를 나눠 리스트로 리턴하는 os 경로 분리자.
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)를 리턴하게 합니다.

# %%
# 11

def decode_img(img):
  # 이미지를 uint8 tensor로 바꾼다.
  img = tf.image.decode_jpeg(img, channels=3)
    
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꾼다.
  img = tf.image.convert_image_dtype(img, tf.float32)
    
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정한다.
  return tf.image.resize(img, IMAGE_SIZE)

# 
def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
# 12

train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# for문을 통해 정의한 데이터셋 확인
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())

# %%
# 13

test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
# 14

def prepare_for_training(ds, shuffle_buffer_size=1000):

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
# 15

image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

# %%
# 16 

def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
# 17 

def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %%
# 18 

weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.93
# Weight for class 1: 0.68

# %%
# 19

with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
# 20

with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 130/130 [==============================] - 37s 288ms/step - loss: 0.4309 - accuracy: 0.7663 - precision: 0.9377 - recall: 0.7331 - val_loss: 0.5674 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 1.0000
# Epoch 2/25
# 130/130 [==============================] - 34s 265ms/step - loss: 0.2217 - accuracy: 0.9118 - precision: 0.9742 - recall: 0.9050 - val_loss: 0.7239 - val_accuracy: 0.7520 - val_precision: 0.7520 - val_recall: 1.0000
# Epoch 3/25
# 130/130 [==============================] - 34s 263ms/step - loss: 0.1680 - accuracy: 0.9399 - precision: 0.9806 - recall: 0.9372 - val_loss: 1.0285 - val_accuracy: 0.7480 - val_precision: 0.7480 - val_recall: 1.0000
# Epoch 4/25
# 130/130 [==============================] - 35s 266ms/step - loss: 0.1351 - accuracy: 0.9481 - precision: 0.9825 - recall: 0.9467 - val_loss: 1.4923 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 1.0000
# Epoch 5/25
# 130/130 [==============================] - 34s 264ms/step - loss: 0.1408 - accuracy: 0.9510 - precision: 0.9826 - recall: 0.9508 - val_loss: 0.7129 - val_accuracy: 0.7549 - val_precision: 0.7532 - val_recall: 1.0000
# Epoch 6/25
# 130/130 [==============================] - 34s 259ms/step - loss: 0.1240 - accuracy: 0.9529 - precision: 0.9849 - recall: 0.9509 - val_loss: 0.1733 - val_accuracy: 0.9248 - val_precision: 0.9105 - val_recall: 0.9974
# Epoch 7/25
# 130/130 [==============================] - 30s 232ms/step - loss: 0.1079 - accuracy: 0.9632 - precision: 0.9877 - recall: 0.9624 - val_loss: 0.0803 - val_accuracy: 0.9707 - val_precision: 0.9683 - val_recall: 0.9935
# Epoch 8/25
# 130/130 [==============================] - 36s 275ms/step - loss: 0.1022 - accuracy: 0.9635 - precision: 0.9886 - recall: 0.9616 - val_loss: 0.0730 - val_accuracy: 0.9727 - val_precision: 0.9793 - val_recall: 0.9844
# Epoch 9/25
# 130/130 [==============================] - 33s 254ms/step - loss: 0.0944 - accuracy: 0.9644 - precision: 0.9893 - recall: 0.9623 - val_loss: 0.0898 - val_accuracy: 0.9707 - val_precision: 0.9854 - val_recall: 0.9751
# Epoch 10/25
# 130/130 [==============================] - 32s 243ms/step - loss: 0.0844 - accuracy: 0.9680 - precision: 0.9910 - recall: 0.9657 - val_loss: 0.1829 - val_accuracy: 0.9336 - val_precision: 0.9986 - val_recall: 0.9124
# Epoch 11/25
# 130/130 [==============================] - 32s 247ms/step - loss: 0.0950 - accuracy: 0.9651 - precision: 0.9890 - recall: 0.9636 - val_loss: 0.1070 - val_accuracy: 0.9580 - val_precision: 0.9548 - val_recall: 0.9909
# Epoch 12/25
# 130/130 [==============================] - 32s 244ms/step - loss: 0.0852 - accuracy: 0.9683 - precision: 0.9877 - recall: 0.9691 - val_loss: 0.2693 - val_accuracy: 0.9160 - val_precision: 1.0000 - val_recall: 0.8877
# Epoch 13/25
# 130/130 [==============================] - 33s 251ms/step - loss: 0.0744 - accuracy: 0.9724 - precision: 0.9934 - recall: 0.9692 - val_loss: 0.0716 - val_accuracy: 0.9736 - val_precision: 0.9792 - val_recall: 0.9856
# Epoch 14/25
# 130/130 [==============================] - 33s 251ms/step - loss: 0.0723 - accuracy: 0.9721 - precision: 0.9910 - recall: 0.9711 - val_loss: 0.0907 - val_accuracy: 0.9736 - val_precision: 0.9881 - val_recall: 0.9765
# Epoch 15/25
# 130/130 [==============================] - 32s 249ms/step - loss: 0.0714 - accuracy: 0.9726 - precision: 0.9911 - recall: 0.9718 - val_loss: 0.0976 - val_accuracy: 0.9717 - val_precision: 0.9973 - val_recall: 0.9647
# Epoch 16/25
# 130/130 [==============================] - 31s 241ms/step - loss: 0.0761 - accuracy: 0.9707 - precision: 0.9914 - recall: 0.9688 - val_loss: 0.0793 - val_accuracy: 0.9727 - val_precision: 0.9933 - val_recall: 0.9699
# Epoch 17/25
# 130/130 [==============================] - 32s 247ms/step - loss: 0.0623 - accuracy: 0.9755 - precision: 0.9934 - recall: 0.9734 - val_loss: 0.1613 - val_accuracy: 0.9492 - val_precision: 0.9986 - val_recall: 0.9334
# Epoch 18/25
# 130/130 [==============================] - 31s 236ms/step - loss: 0.0603 - accuracy: 0.9764 - precision: 0.9937 - recall: 0.9744 - val_loss: 0.0932 - val_accuracy: 0.9717 - val_precision: 0.9946 - val_recall: 0.9674
# Epoch 19/25
# 130/130 [==============================] - 33s 258ms/step - loss: 0.0573 - accuracy: 0.9796 - precision: 0.9954 - recall: 0.9770 - val_loss: 0.0707 - val_accuracy: 0.9775 - val_precision: 0.9869 - val_recall: 0.9830
# Epoch 20/25
# 130/130 [==============================] - 31s 238ms/step - loss: 0.0521 - accuracy: 0.9796 - precision: 0.9960 - recall: 0.9762 - val_loss: 0.7915 - val_accuracy: 0.7852 - val_precision: 1.0000 - val_recall: 0.7150
# Epoch 21/25
# 130/130 [==============================] - 35s 271ms/step - loss: 0.0548 - accuracy: 0.9803 - precision: 0.9947 - recall: 0.9786 - val_loss: 0.2465 - val_accuracy: 0.9277 - val_precision: 1.0000 - val_recall: 0.9038
# Epoch 22/25
# 130/130 [==============================] - 32s 250ms/step - loss: 0.0496 - accuracy: 0.9822 - precision: 0.9960 - recall: 0.9799 - val_loss: 0.0699 - val_accuracy: 0.9814 - val_precision: 0.9883 - val_recall: 0.9870
# Epoch 23/25
# 130/130 [==============================] - 33s 254ms/step - loss: 0.0483 - accuracy: 0.9820 - precision: 0.9961 - recall: 0.9796 - val_loss: 0.1052 - val_accuracy: 0.9629 - val_precision: 0.9986 - val_recall: 0.9518
# Epoch 24/25
# 130/130 [==============================] - 33s 253ms/step - loss: 0.0551 - accuracy: 0.9796 - precision: 0.9943 - recall: 0.9778 - val_loss: 0.1146 - val_accuracy: 0.9717 - val_precision: 0.9946 - val_recall: 0.9673
# Epoch 25/25
# 130/130 [==============================] - 33s 251ms/step - loss: 0.0494 - accuracy: 0.9827 - precision: 0.9961 - recall: 0.9806 - val_loss: 0.1196 - val_accuracy: 0.9678 - val_precision: 0.9933 - val_recall: 0.9635

# %%
# 21

fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
# 22

loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 20/20 [==============================] - 4s 191ms/step - loss: 0.8171 - accuracy: 0.8397 - precision: 0.8021 - recall: 0.9872
