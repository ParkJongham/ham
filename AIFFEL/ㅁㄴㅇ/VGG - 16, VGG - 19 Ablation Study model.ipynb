# %%
# 필요 라이브러리 임포트

import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
import urllib3
import matplotlib.pyplot as plt

tf.config.list_physical_devices('GPU')
urllib3.disable_warnings()

tfds.disable_progress_bar()

# %%
# 데이터셋 다운로드
# tfds.load()는 기본적으로 ~/tensorflow_datasets 경로에 데이터셋을 다운
# 데이터셋 경로를 바꾸고 싶으시다면, data_dir 인자를 사용

(ds_train, ds_test), ds_info = tfds.load('cifar10', split = ['train', 'test'], shuffle_files = True, with_info = True)

# %%
# 다운받은 데이터셋 feature 정보 확인

print(ds_info.features)
# Out:
# FeaturesDict({
#     'id': Text(shape=(), dtype=tf.string),
#     'image': Image(shape=(32, 32, 3), dtype=tf.uint8),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
# })

# %%
# 데이터의 개수 확인
# tensorflow 데이터셋은 numpy 가 아니기 때문에 ds_train.shape로 확인하지 않는다.

print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(50000, shape=(), dtype=int64)
# tf.Tensor(10000, shape=(), dtype=int64)

# %%
# input normalization
# 각 채널별 최대값인 255로 정규화

def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    # image = tf.image.resize(image, [32, 32])
    return tf.cast(image, tf.float32) / 255., label

def apply_normalize_on_dataset(ds, is_test = False, batch_size = 16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
# CIFAR - 10 이 가지는 클래스 수 및 클래스명 확인

ds_info.features['label'].num_classes
# Out:
# 10

# %%
ds_info.features['label'].names
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
fig = tfds.show_examples(ds_train, ds_info)

# %%
fig = tfds.show_examples(ds_test, ds_info)

# %%
# VGG 블록 구성

def build_vgg_block(input_layer, num_cnn = 3, channel = 64, block_num = 1) : 
    x = input_layer    # 입력 레이어
    
    # CNN 레이어
    for cnn_num in range(num_cnn) : 
        x = keras.layers.Conv2D(filters = channel, kernel_size = (3, 3), activation = 'relu', kernel_initializer = 'he_normal', padding = 'same', name = f'block{block_num}_conv{cnn_num}')(x)
    
    # MaxPooling 레이어
    x = keras.layers.MaxPooling2D(pool_size = (2, 2), strides = 2, name = f'block{block_num}_pooling')(x)
    
    return x

# %%
# VGG 블록을 추가하는 함수를 통해 input_layer 에 추가
# 입력 레이어를 인자로 building_vgg_block() 블록의 레이어를 build, 출력
# keras 의 Model 클래스에서 input 과 output 을 정의함으로 블록의 모델 확인

# 입력 레이어 생성
vgg_input_layer = keras.layers.Input(shape = (32, 32, 3))

# VGG 블록 생성
vgg_block_output = build_vgg_block(vgg_input_layer)

# %%
# 블록 1개짜리 model 생성

model = keras.Model(inputs = vgg_input_layer, outputs = vgg_block_output)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_conv0 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pooling (MaxPooling2D (None, 16, 16, 64)        0
# =================================================================
# Total params: 75,648
# Trainable params: 75,648
# Non-trainable params: 0
# _________________________________________________________________

# %%
# VGG - 16 모델 생성

def build_vgg(input_shape = (32, 32, 3), num_cnn_list = [2, 2, 3, 3, 3], channel_list = [64, 128, 256, 512, 512], num_classes = 10) : 
    assert len(num_cnn_list) == len(channel_list)    # 모델을 만들기 전에 config list 들이 같은 길이인지 확인
    
    input_layer = keras.layers.Input(shape = input_shape)    # input layer 를 생성
    output = input_layer
    
    # config list 들의 길이만큼 반복하면서 블록 생성
    for i, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)) : 
        output = build_vgg_block(output, num_cnn = num_cnn, channel = channel, block_num = i)
        
    output = keras.layers.Flatten(name = 'flatten')(output)
    output = keras.layers.Dense(4096, activation = 'relu', name = 'fc1')(output)
    output = keras.layers.Dense(4096, activation = 'relu', name = 'fc2')(output)
    output = keras.layers.Dense(num_classes, activation = 'softmax', name = 'predictions')(output)
    
    model = keras.Model(inputs = input_layer, outputs = output)
    
    return model

# %%
# 기본값을 사용해 VGG 모델을 만들면 VGG - 16 모델 생성 완료

vgg_16 = build_vgg()

vgg_16.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block0_conv0 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block0_conv1 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block0_pooling (MaxPooling2D (None, 16, 16, 64)        0
# _________________________________________________________________
# block1_conv0 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block1_pooling (MaxPooling2D (None, 8, 8, 128)         0
# _________________________________________________________________
# block2_conv0 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_pooling (MaxPooling2D (None, 4, 4, 256)         0
# _________________________________________________________________
# block3_conv0 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_pooling (MaxPooling2D (None, 2, 2, 512)         0
# _________________________________________________________________
# block4_conv0 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_pooling (MaxPooling2D (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              2101248
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 10)                40970
# =================================================================
# Total params: 33,638,218
# Trainable params: 33,638,218
# Non-trainable params: 0
# _________________________________________________________________

# %%
# VGG - 16 구성 변경을 통한 VGG - 19 생성

# 원하는 블록의 설계에 따라 매개변수로 리스트를 전달
vgg_19 = build_vgg(num_cnn_list = [2, 2, 4, 4, 4], channel_list = [64, 128, 256, 512, 512])

vgg_19.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block0_conv0 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block0_conv1 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block0_pooling (MaxPooling2D (None, 16, 16, 64)        0
# _________________________________________________________________
# block1_conv0 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block1_pooling (MaxPooling2D (None, 8, 8, 128)         0
# _________________________________________________________________
# block2_conv0 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_pooling (MaxPooling2D (None, 4, 4, 256)         0
# _________________________________________________________________
# block3_conv0 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_pooling (MaxPooling2D (None, 2, 2, 512)         0
# _________________________________________________________________
# block4_conv0 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_pooling (MaxPooling2D (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              2101248
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 10)                40970
# =================================================================
# Total params: 38,947,914
# Trainable params: 38,947,914
# Non-trainable params: 0
# _________________________________________________________________

# %%
# VGG - 16 과 VGG - 19 비교

BATCH_SIZE = 256
EPOCH = 40

# %%
# CIFAR - 10 데이터셋 불러오기

(ds_train, ds_test), ds_info = tfds.load('cifar10', split = ['train', 'test'], as_supervised = True, shuffle_files = True, with_info = True)

ds_train = apply_normalize_on_dataset(ds_train, batch_size = BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size = BATCH_SIZE)

# %%
vgg_16.compile(
    loss = 'sparse_categorical_crossentropy',
    optimizer = tf.keras.optimizers.SGD(lr = 0.01, clipnorm = 1.),
    metrics = ['accuracy']
)

history_16 = vgg_16.fit(
    ds_train,
    steps_per_epoch = int(ds_info.splits['train'].num_examples / BATCH_SIZE),
    validation_steps = int(ds_info.splits['test'].num_examples / BATCH_SIZE),
    epochs = EPOCH,
    validation_data = ds_test,
    verbose = 1,
    use_multiprocessing = True,
)
# Out:
# Epoch 1/40
# 195/195 [==============================] - 47s 243ms/step - loss: 2.1656 - accuracy: 0.2031 - val_loss: 2.0875 - val_accuracy: 0.2486
# Epoch 2/40
# 195/195 [==============================] - 17s 85ms/step - loss: 1.9788 - accuracy: 0.2889 - val_loss: 1.8784 - val_accuracy: 0.3453
# Epoch 3/40
# 195/195 [==============================] - 17s 85ms/step - loss: 1.8422 - accuracy: 0.3446 - val_loss: 1.7935 - val_accuracy: 0.3504
# Epoch 4/40
# 195/195 [==============================] - 17s 87ms/step - loss: 1.7475 - accuracy: 0.3736 - val_loss: 1.7231 - val_accuracy: 0.3836
# Epoch 5/40
# 195/195 [==============================] - 17s 89ms/step - loss: 1.6783 - accuracy: 0.4008 - val_loss: 1.6456 - val_accuracy: 0.4038
# Epoch 6/40
# 195/195 [==============================] - 18s 91ms/step - loss: 1.6244 - accuracy: 0.4212 - val_loss: 1.5958 - val_accuracy: 0.4139
# Epoch 7/40
# 195/195 [==============================] - 17s 88ms/step - loss: 1.5668 - accuracy: 0.4380 - val_loss: 1.5338 - val_accuracy: 0.4478
# Epoch 8/40
# 195/195 [==============================] - 17s 87ms/step - loss: 1.5136 - accuracy: 0.4587 - val_loss: 1.4864 - val_accuracy: 0.4699
# Epoch 9/40
# 195/195 [==============================] - 17s 87ms/step - loss: 1.4789 - accuracy: 0.4713 - val_loss: 1.4532 - val_accuracy: 0.4731
# Epoch 10/40
# 195/195 [==============================] - 17s 88ms/step - loss: 1.4414 - accuracy: 0.4830 - val_loss: 1.4026 - val_accuracy: 0.5036
# Epoch 11/40
# 195/195 [==============================] - 17s 89ms/step - loss: 1.3982 - accuracy: 0.4998 - val_loss: 1.3770 - val_accuracy: 0.5076
# Epoch 12/40
# 195/195 [==============================] - 18s 91ms/step - loss: 1.3621 - accuracy: 0.5117 - val_loss: 1.4081 - val_accuracy: 0.4889
# Epoch 13/40
# 195/195 [==============================] - 17s 90ms/step - loss: 1.3291 - accuracy: 0.5236 - val_loss: 1.3703 - val_accuracy: 0.5042
# Epoch 14/40
# 195/195 [==============================] - 17s 88ms/step - loss: 1.3003 - accuracy: 0.5363 - val_loss: 1.3110 - val_accuracy: 0.5250
# Epoch 15/40
# 195/195 [==============================] - 18s 92ms/step - loss: 1.2511 - accuracy: 0.5516 - val_loss: 1.2680 - val_accuracy: 0.5454
# Epoch 16/40
# 195/195 [==============================] - 18s 93ms/step - loss: 1.2344 - accuracy: 0.5602 - val_loss: 1.2585 - val_accuracy: 0.5495
# Epoch 17/40
# 195/195 [==============================] - 17s 89ms/step - loss: 1.2022 - accuracy: 0.5705 - val_loss: 1.2455 - val_accuracy: 0.5456
# Epoch 18/40
# 195/195 [==============================] - 17s 87ms/step - loss: 1.1688 - accuracy: 0.5848 - val_loss: 1.2501 - val_accuracy: 0.5513
# Epoch 19/40
# 195/195 [==============================] - 17s 87ms/step - loss: 1.1397 - accuracy: 0.5958 - val_loss: 1.2129 - val_accuracy: 0.5674
# Epoch 20/40
# 195/195 [==============================] - 17s 88ms/step - loss: 1.1099 - accuracy: 0.6091 - val_loss: 1.2216 - val_accuracy: 0.5683
# Epoch 21/40
# 195/195 [==============================] - 17s 88ms/step - loss: 1.0848 - accuracy: 0.6166 - val_loss: 1.1869 - val_accuracy: 0.5781
# Epoch 22/40
# 195/195 [==============================] - 17s 87ms/step - loss: 1.0504 - accuracy: 0.6277 - val_loss: 1.1423 - val_accuracy: 0.6000
# Epoch 23/40
# 195/195 [==============================] - 17s 87ms/step - loss: 1.0328 - accuracy: 0.6351 - val_loss: 1.1565 - val_accuracy: 0.5914
# Epoch 24/40
# 195/195 [==============================] - 17s 88ms/step - loss: 0.9965 - accuracy: 0.6472 - val_loss: 1.1184 - val_accuracy: 0.6092
# Epoch 25/40
# 195/195 [==============================] - 17s 87ms/step - loss: 0.9802 - accuracy: 0.6533 - val_loss: 1.1261 - val_accuracy: 0.6062
# Epoch 26/40
# 195/195 [==============================] - 17s 87ms/step - loss: 0.9536 - accuracy: 0.6627 - val_loss: 1.1478 - val_accuracy: 0.6033
# Epoch 27/40
# 195/195 [==============================] - 17s 87ms/step - loss: 0.9297 - accuracy: 0.6725 - val_loss: 1.0924 - val_accuracy: 0.6102
# Epoch 28/40
# 195/195 [==============================] - 17s 87ms/step - loss: 0.8966 - accuracy: 0.6849 - val_loss: 1.1800 - val_accuracy: 0.5925
# Epoch 29/40
# 195/195 [==============================] - 17s 87ms/step - loss: 0.8762 - accuracy: 0.6919 - val_loss: 1.1409 - val_accuracy: 0.6004
# Epoch 30/40
# 195/195 [==============================] - 17s 87ms/step - loss: 0.8554 - accuracy: 0.7009 - val_loss: 1.1196 - val_accuracy: 0.6013
# Epoch 31/40
# 195/195 [==============================] - 17s 87ms/step - loss: 0.8237 - accuracy: 0.7109 - val_loss: 1.1030 - val_accuracy: 0.6142
# Epoch 32/40
# 195/195 [==============================] - 17s 87ms/step - loss: 0.7997 - accuracy: 0.7164 - val_loss: 1.0860 - val_accuracy: 0.6308
# Epoch 33/40
# 195/195 [==============================] - 17s 88ms/step - loss: 0.7840 - accuracy: 0.7228 - val_loss: 1.1478 - val_accuracy: 0.6118
# Epoch 34/40
# 195/195 [==============================] - 17s 89ms/step - loss: 0.7517 - accuracy: 0.7338 - val_loss: 1.1094 - val_accuracy: 0.6229
# Epoch 35/40
# 195/195 [==============================] - 18s 91ms/step - loss: 0.7267 - accuracy: 0.7444 - val_loss: 1.1194 - val_accuracy: 0.6210
# Epoch 36/40
# 195/195 [==============================] - 17s 89ms/step - loss: 0.7108 - accuracy: 0.7504 - val_loss: 1.1093 - val_accuracy: 0.6306
# Epoch 37/40
# 195/195 [==============================] - 17s 89ms/step - loss: 0.6856 - accuracy: 0.7581 - val_loss: 1.1111 - val_accuracy: 0.6375
# Epoch 38/40
# 195/195 [==============================] - 17s 89ms/step - loss: 0.6607 - accuracy: 0.7666 - val_loss: 1.1686 - val_accuracy: 0.6126
# Epoch 39/40
# 195/195 [==============================] - 17s 89ms/step - loss: 0.6313 - accuracy: 0.7784 - val_loss: 1.1911 - val_accuracy: 0.6154
# Epoch 40/40
# 195/195 [==============================] - 17s 88ms/step - loss: 0.6054 - accuracy: 0.7880 - val_loss: 1.1311 - val_accuracy: 0.6307

# %%
# VGG - 19 모델 생성 및 훈련

vgg_19.compile(
    loss = 'sparse_categorical_crossentropy',
    optimizer = tf.keras.optimizers.SGD(lr = 0.01, clipnorm = 1.),
    metrics = ['accuracy'],
)

history_19 = vgg_19.fit(
    ds_train,
    steps_per_epoch = int(ds_info.splits['train'].num_examples / BATCH_SIZE),
    validation_steps = int(ds_info.splits['test'].num_examples / BATCH_SIZE),
    epochs = EPOCH,
    validation_data = ds_test,
    verbose = 1,
    use_multiprocessing = True,
)
# Out:
# Epoch 1/40
# 195/195 [==============================] - 20s 105ms/step - loss: 2.2304 - accuracy: 0.1699 - val_loss: 2.1084 - val_accuracy: 0.2498
# Epoch 2/40
# 195/195 [==============================] - 20s 105ms/step - loss: 2.0440 - accuracy: 0.2525 - val_loss: 1.9637 - val_accuracy: 0.3031
# Epoch 3/40
# 195/195 [==============================] - 20s 105ms/step - loss: 1.9066 - accuracy: 0.3096 - val_loss: 1.8190 - val_accuracy: 0.3426
# Epoch 4/40
# 195/195 [==============================] - 20s 105ms/step - loss: 1.7869 - accuracy: 0.3585 - val_loss: 1.7430 - val_accuracy: 0.3782
# Epoch 5/40
# 195/195 [==============================] - 20s 105ms/step - loss: 1.7032 - accuracy: 0.3852 - val_loss: 1.6409 - val_accuracy: 0.3933
# Epoch 6/40
# 195/195 [==============================] - 20s 105ms/step - loss: 1.6364 - accuracy: 0.4093 - val_loss: 1.6064 - val_accuracy: 0.4053
# Epoch 7/40
# 195/195 [==============================] - 20s 105ms/step - loss: 1.5702 - accuracy: 0.4324 - val_loss: 1.5948 - val_accuracy: 0.4446
# Epoch 8/40
# 195/195 [==============================] - 20s 105ms/step - loss: 1.5260 - accuracy: 0.4490 - val_loss: 1.5129 - val_accuracy: 0.4422
# Epoch 9/40
# 195/195 [==============================] - 21s 107ms/step - loss: 1.4724 - accuracy: 0.4702 - val_loss: 1.4579 - val_accuracy: 0.4699
# Epoch 10/40
# 195/195 [==============================] - 21s 105ms/step - loss: 1.4380 - accuracy: 0.4826 - val_loss: 1.3840 - val_accuracy: 0.5008
# Epoch 11/40
# 195/195 [==============================] - 21s 105ms/step - loss: 1.3880 - accuracy: 0.5015 - val_loss: 1.3847 - val_accuracy: 0.5113
# Epoch 12/40
# 195/195 [==============================] - 21s 105ms/step - loss: 1.3479 - accuracy: 0.5165 - val_loss: 1.3616 - val_accuracy: 0.5118
# Epoch 13/40
# 195/195 [==============================] - 20s 105ms/step - loss: 1.3119 - accuracy: 0.5307 - val_loss: 1.3136 - val_accuracy: 0.5299
# Epoch 14/40
# 195/195 [==============================] - 20s 105ms/step - loss: 1.2610 - accuracy: 0.5502 - val_loss: 1.3046 - val_accuracy: 0.5282
# Epoch 15/40
# 195/195 [==============================] - 21s 106ms/step - loss: 1.2312 - accuracy: 0.5611 - val_loss: 1.2602 - val_accuracy: 0.5455
# Epoch 16/40
# 195/195 [==============================] - 21s 105ms/step - loss: 1.2040 - accuracy: 0.5699 - val_loss: 1.2539 - val_accuracy: 0.5559
# Epoch 17/40
# 195/195 [==============================] - 21s 106ms/step - loss: 1.1608 - accuracy: 0.5858 - val_loss: 1.2257 - val_accuracy: 0.5592
# Epoch 18/40
# 195/195 [==============================] - 21s 105ms/step - loss: 1.1257 - accuracy: 0.5982 - val_loss: 1.2249 - val_accuracy: 0.5686
# Epoch 19/40
# 195/195 [==============================] - 21s 105ms/step - loss: 1.1010 - accuracy: 0.6093 - val_loss: 1.1763 - val_accuracy: 0.5910
# Epoch 20/40
# 195/195 [==============================] - 21s 106ms/step - loss: 1.0586 - accuracy: 0.6235 - val_loss: 1.1851 - val_accuracy: 0.5870
# Epoch 21/40
# 195/195 [==============================] - 21s 106ms/step - loss: 1.0320 - accuracy: 0.6350 - val_loss: 1.1442 - val_accuracy: 0.5959
# Epoch 22/40
# 195/195 [==============================] - 21s 106ms/step - loss: 0.9950 - accuracy: 0.6480 - val_loss: 1.1596 - val_accuracy: 0.5875
# Epoch 23/40
# 195/195 [==============================] - 21s 106ms/step - loss: 0.9730 - accuracy: 0.6532 - val_loss: 1.1443 - val_accuracy: 0.5939
# Epoch 24/40
# 195/195 [==============================] - 21s 106ms/step - loss: 0.9450 - accuracy: 0.6664 - val_loss: 1.1001 - val_accuracy: 0.6219
# Epoch 25/40
# 195/195 [==============================] - 21s 106ms/step - loss: 0.9145 - accuracy: 0.6753 - val_loss: 1.0854 - val_accuracy: 0.6237
# Epoch 26/40
# 195/195 [==============================] - 21s 106ms/step - loss: 0.8844 - accuracy: 0.6858 - val_loss: 1.1381 - val_accuracy: 0.6039
# Epoch 27/40
# 195/195 [==============================] - 21s 106ms/step - loss: 0.8513 - accuracy: 0.6965 - val_loss: 1.1181 - val_accuracy: 0.6155
# Epoch 28/40
# 195/195 [==============================] - 21s 106ms/step - loss: 0.8125 - accuracy: 0.7128 - val_loss: 1.0633 - val_accuracy: 0.6276
# Epoch 29/40
# 195/195 [==============================] - 21s 106ms/step - loss: 0.8020 - accuracy: 0.7164 - val_loss: 1.1874 - val_accuracy: 0.6028
# Epoch 30/40
# 195/195 [==============================] - 21s 106ms/step - loss: 0.7641 - accuracy: 0.7325 - val_loss: 1.1025 - val_accuracy: 0.6286
# Epoch 31/40
# 195/195 [==============================] - 21s 106ms/step - loss: 0.7417 - accuracy: 0.7381 - val_loss: 1.0797 - val_accuracy: 0.6345
# Epoch 32/40
# 195/195 [==============================] - 21s 105ms/step - loss: 0.7119 - accuracy: 0.7492 - val_loss: 1.1041 - val_accuracy: 0.6283
# Epoch 33/40
# 195/195 [==============================] - 21s 107ms/step - loss: 0.6782 - accuracy: 0.7602 - val_loss: 1.1121 - val_accuracy: 0.6281
# Epoch 34/40
# 195/195 [==============================] - 21s 110ms/step - loss: 0.6540 - accuracy: 0.7684 - val_loss: 1.1496 - val_accuracy: 0.6256
# Epoch 35/40
# 195/195 [==============================] - 21s 107ms/step - loss: 0.6197 - accuracy: 0.7815 - val_loss: 1.1175 - val_accuracy: 0.6359
# Epoch 36/40
# 195/195 [==============================] - 20s 103ms/step - loss: 0.5979 - accuracy: 0.7893 - val_loss: 1.1585 - val_accuracy: 0.6366
# Epoch 37/40
# 195/195 [==============================] - 20s 103ms/step - loss: 0.5620 - accuracy: 0.8048 - val_loss: 1.1962 - val_accuracy: 0.6272
# Epoch 38/40
# 195/195 [==============================] - 20s 103ms/step - loss: 0.5424 - accuracy: 0.8072 - val_loss: 1.1531 - val_accuracy: 0.6290
# Epoch 39/40
# 195/195 [==============================] - 20s 103ms/step - loss: 0.5130 - accuracy: 0.8215 - val_loss: 1.1822 - val_accuracy: 0.6368
# Epoch 40/40
# 195/195 [==============================] - 20s 104ms/step - loss: 0.4831 - accuracy: 0.8296 - val_loss: 1.1544 - val_accuracy: 0.6457

# %%
# VGG - 16, VGG - 19 의 학습과정을 그래프로 시각화
# training loss 과정을 확인

plt.plot(history_16.history['loss'], 'r')
plt.plot(history_19.history['loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['vgg_16', 'vgg_19'], loc='upper left')
plt.show()

# %%
# VGG - 16 과 VGG - 19 이검증 정확도 (validation acuuracy) 비교

plt.plot(history_16.history['val_accuracy'], 'r')
plt.plot(history_19.history['val_accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['vgg_16', 'vgg_19'], loc='upper left')
plt.show()
