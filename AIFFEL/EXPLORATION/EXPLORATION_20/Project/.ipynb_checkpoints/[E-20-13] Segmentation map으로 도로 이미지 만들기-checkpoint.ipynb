# %% [markdown]
# # 프로젝트 : Segmentation map으로 도로 이미지 만들기
#
# 이전 Pix2Pix 논문에서 제시한 결과 중에 아래와 같은 실험 결과가 있었습니다. 도로의 레이블 정보를 활용해 이미지를 생성해낸 결과입니다.
# <br></br>
# ![](https://aiffelstaticprd.blob.core.windows.net/media/images/p2p_result_seg.max-800x600.png)
# <br></br>
# 이번 프로젝트는 위와 같은 데이터셋을 이용해 Pix2Pix를 학습시켜보는 것입니다. 데이터셋은 아래에서 다운로드할 수 있습니다.
# 1000개의 학습용 이미지 및 5개의 평가 이미지를 포함합니다.
#
# + [데이터셋 : cityscapes](https://aiffelstaticprd.blob.core.windows.net/media/documents/cityscapes.zip)
# <br></br>
# 이전 포켓몬 데이터에서 사용했던 스케치와는 조금 다른 레이블 정보 이미지를 입력으로 사용하기 때문에, 전처리 과정에 대해 약간의 혼란이 있을 수 있지만 크게 다른 과정은 없습니다.
# 아래 Tensroflow에서 제공하는 Pix2Pix 튜토리얼은 위 이미지와 비슷한 레이블 정보 이미지를 사용하기 때문에 좋은 참고 자료가 될 수 있을 것 같습니다.
#
# 프로젝트 시작에 어려움이 있다면 아래 튜토리얼을 참고하시면서 이번 프로젝트를 수행해봅시다.
# (아래 튜토리얼은 Pix2Pix 구조를 Functional API를 이용해 구현하기 때문에 이번에 진행한 Subclassing 방법을 이용한 모델 구현과 비교하면서 구현 방법에 대해서도 공부해 보시길 추천드립니다)
#
# + 참고 : [Tensorflow Pix2Pix Tutorial](https://www.tensorflow.org/tutorials/generative/pix2pix?hl=ko)
# <br></br>
#
# ### 프로젝트 수행
#
# ----------
#
# 프로젝트를 진행하면서 필수로 수행해야 할 사항은 다음과 같습니다.
#
# 1.  데이터에 한 가지 이상의  **augmentation 방법을 적용**하여 학습해주세요.
#     (어떠한 방법을 사용했는지 적어주세요.)
#
# 2.  이전에 구현했던 두 개의 Generator 중 Encoder와 Decoder간에 skip connection이 있는  **U-Net Generator를 사용**해주세요.
#
# 3.  모델 학습 후, 학습된 Generator를 이용해 테스트합니다. 테스트 데이터는 다운받았던 "val" 폴더 내 이미지를 사용해주세요.
#
# 4.  1개 이상의 이미지에 대해 테스트 과정을 거친 후 그 결과를  **스케치, 생성된 사진, 실제 사진 순서로 나란히 시각화**해 주세요.
#
# 5.  모델을 충분히 학습하기에 시간이 부족할 수 있습니다. 적어도 10 epoch 이상 학습하며  **중간 손실 값에 대한 로그**를 남겨주세요. 좋은 결과를 얻기 위해선 긴 학습 시간이 필요하므로 테스트 결과는 만족스럽지 않아도 괜찮습니다.
# ***

# %% [markdown]
# ## 1. 데이터에 한 가지 이상의 augmentation 방법을 적용 하여 학습해주세요. (어떠한 방법을 사용했는지 적어주세요.)

# %%
import os

data_path = os.getenv('HOME')+'/aiffel/conditional_generation/pokemon_pix2pix_dataset/train/'
val_data_path = os.getenv('HOME')+'/aiffel/conditional_generation/cityscapes/val/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 830

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu= layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

# %%
class Encoder(layers.Layer):
    def __init__(self):
        super(Encoder, self).__init__()
        filters = [64,128,256,512,512,512,512,512]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i == 0:
                self.blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.blocks.append(EncodeBlock(f))
    
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
    
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
Encoder().get_summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encode_block (EncodeBlock)   (None, 128, 128, 64)      3072
# _________________________________________________________________
# encode_block_1 (EncodeBlock) (None, 64, 64, 128)       131584
# _________________________________________________________________
# encode_block_2 (EncodeBlock) (None, 32, 32, 256)       525312
# _________________________________________________________________
# encode_block_3 (EncodeBlock) (None, 16, 16, 512)       2099200
# _________________________________________________________________
# encode_block_4 (EncodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# encode_block_5 (EncodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# encode_block_6 (EncodeBlock) (None, 2, 2, 512)         4196352
# _________________________________________________________________
# encode_block_7 (EncodeBlock) (None, 1, 1, 512)         4196352
# =================================================================
# Total params: 19,544,576
# Trainable params: 19,538,688
# Non-trainable params: 5,888
# _________________________________________________________________

# %%
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

    
class Decoder(layers.Layer):
    def __init__(self):
        super(Decoder, self).__init__()
        filters = [512,512,512,512,256,128,64]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i < 3:
                self.blocks.append(DecodeBlock(f))
            else:
                self.blocks.append(DecodeBlock(f, dropout=False))
                
        self.blocks.append(layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False))
        
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
            
    def get_summary(self, input_shape=(1,1,256)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
class EncoderDecoderGenerator(Model):
    def __init__(self):
        super(EncoderDecoderGenerator, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def call(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
   
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
        

EncoderDecoderGenerator().get_summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encoder_1 (Encoder)          (None, 1, 1, 512)         19544576
# _________________________________________________________________
# decoder (Decoder)            (None, 256, 256, 3)       19542784
# =================================================================
# Total params: 39,087,360
# Trainable params: 39,076,480
# Non-trainable params: 10,880
# _________________________________________________________________

# %%
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %% [markdown]
# ## 2. 이전에 구현했던 두 개의 Generator 중 Encoder와 Decoder간에 skip connection이 있는 U-Net Generator를 사용 해주세요.

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block_16 (EncodeBlock)   (None, 128, 128, 64) 3072        input_3[0][0]
# __________________________________________________________________________________________________
# encode_block_17 (EncodeBlock)   (None, 64, 64, 128)  131584      encode_block_16[0][0]
# __________________________________________________________________________________________________
# encode_block_18 (EncodeBlock)   (None, 32, 32, 256)  525312      encode_block_17[0][0]
# __________________________________________________________________________________________________
# encode_block_19 (EncodeBlock)   (None, 16, 16, 512)  2099200     encode_block_18[0][0]
# __________________________________________________________________________________________________
# encode_block_20 (EncodeBlock)   (None, 8, 8, 512)    4196352     encode_block_19[0][0]
# __________________________________________________________________________________________________
# encode_block_21 (EncodeBlock)   (None, 4, 4, 512)    4196352     encode_block_20[0][0]
# __________________________________________________________________________________________________
# encode_block_22 (EncodeBlock)   (None, 2, 2, 512)    4196352     encode_block_21[0][0]
# __________________________________________________________________________________________________
# encode_block_23 (EncodeBlock)   (None, 1, 1, 512)    4196352     encode_block_22[0][0]
# __________________________________________________________________________________________________
# decode_block_7 (DecodeBlock)    (None, 2, 2, 512)    4196352     encode_block_23[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block_7[0][0]
#                                                                  encode_block_22[0][0]
# __________________________________________________________________________________________________
# decode_block_8 (DecodeBlock)    (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_8[0][0]
#                                                                  encode_block_21[0][0]
# __________________________________________________________________________________________________
# decode_block_9 (DecodeBlock)    (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_9[0][0]
#                                                                  encode_block_20[0][0]
# __________________________________________________________________________________________________
# decode_block_10 (DecodeBlock)   (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_10[0][0]
#                                                                  encode_block_19[0][0]
# __________________________________________________________________________________________________
# decode_block_11 (DecodeBlock)   (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_11[0][0]
#                                                                  encode_block_18[0][0]
# __________________________________________________________________________________________________
# decode_block_12 (DecodeBlock)   (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_12[0][0]
#                                                                  encode_block_17[0][0]
# __________________________________________________________________________________________________
# decode_block_13 (DecodeBlock)   (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_13[0][0]
#                                                                  encode_block_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 10

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:0.9605
# L1_loss:0.5294
# Discriminator_loss:1.2076
#
# EPOCH[1] - STEP[20]
# Generator_loss:0.9795
# L1_loss:0.3258
# Discriminator_loss:2.3041
#
# EPOCH[1] - STEP[30]
# Generator_loss:0.8592
# L1_loss:0.2952
# Discriminator_loss:1.2201
#
# EPOCH[1] - STEP[40]
# Generator_loss:0.8569
# L1_loss:0.3009
# Discriminator_loss:1.1079
#
# EPOCH[1] - STEP[50]
# Generator_loss:1.4348
# L1_loss:0.2796
# Discriminator_loss:0.8433
#
# EPOCH[1] - STEP[60]
# Generator_loss:1.8415
# L1_loss:0.2765
# Discriminator_loss:0.5810
#
# EPOCH[1] - STEP[70]
# Generator_loss:1.2189
# L1_loss:0.3001
# Discriminator_loss:0.6647
#
# EPOCH[1] - STEP[80]
# Generator_loss:1.8478
# L1_loss:0.2326
# Discriminator_loss:0.5048
#
# EPOCH[1] - STEP[90]
# Generator_loss:2.4998
# L1_loss:0.1966
# Discriminator_loss:1.1501
#
# EPOCH[1] - STEP[100]
# Generator_loss:1.6439
# L1_loss:0.3001
# Discriminator_loss:0.4611
#
# EPOCH[1] - STEP[110]
# Generator_loss:2.3073
# L1_loss:0.2441
# Discriminator_loss:0.7889
#
# EPOCH[1] - STEP[120]
# Generator_loss:2.3063
# L1_loss:0.2151
# Discriminator_loss:0.7886
#
# EPOCH[1] - STEP[130]
# Generator_loss:1.9458
# L1_loss:0.2471
# Discriminator_loss:0.3677
#
# EPOCH[1] - STEP[140]
# Generator_loss:1.9879
# L1_loss:0.2867
# Discriminator_loss:0.2970
#
# EPOCH[1] - STEP[150]
# Generator_loss:0.6738
# L1_loss:0.2673
# Discriminator_loss:1.4402
#
# EPOCH[1] - STEP[160]
# Generator_loss:1.2866
# L1_loss:0.1922
# Discriminator_loss:0.8074
#
# EPOCH[1] - STEP[170]
# Generator_loss:1.9699
# L1_loss:0.2607
# Discriminator_loss:0.3484
#
# EPOCH[1] - STEP[180]
# Generator_loss:2.7052
# L1_loss:0.2578
# Discriminator_loss:0.7583
#
# EPOCH[1] - STEP[190]
# Generator_loss:0.4414
# L1_loss:0.2213
# Discriminator_loss:1.2185
#
# EPOCH[1] - STEP[200]
# Generator_loss:0.1813
# L1_loss:0.2368
# Discriminator_loss:2.2251
#
# EPOCH[2] - STEP[10]
# Generator_loss:2.0661
# L1_loss:0.2477
# Discriminator_loss:0.7787
#
# EPOCH[2] - STEP[20]
# Generator_loss:1.4307
# L1_loss:0.2218
# Discriminator_loss:0.4040
#
# EPOCH[2] - STEP[30]
# Generator_loss:0.6868
# L1_loss:0.2323
# Discriminator_loss:0.9100
#
# EPOCH[2] - STEP[40]
# Generator_loss:2.0929
# L1_loss:0.3136
# Discriminator_loss:0.3298
#
# EPOCH[2] - STEP[50]
# Generator_loss:2.0019
# L1_loss:0.2296
# Discriminator_loss:0.4228
#
# EPOCH[2] - STEP[60]
# Generator_loss:2.0791
# L1_loss:0.2857
# Discriminator_loss:0.7999
#
# EPOCH[2] - STEP[70]
# Generator_loss:2.1797
# L1_loss:0.2177
# Discriminator_loss:0.2140
#
# EPOCH[2] - STEP[80]
# Generator_loss:1.6642
# L1_loss:0.2484
# Discriminator_loss:0.4892
#
# EPOCH[2] - STEP[90]
# Generator_loss:2.2111
# L1_loss:0.2058
# Discriminator_loss:0.5580
#
# EPOCH[2] - STEP[100]
# Generator_loss:0.7424
# L1_loss:0.3179
# Discriminator_loss:0.7600
#
# EPOCH[2] - STEP[110]
# Generator_loss:2.1464
# L1_loss:0.2077
# Discriminator_loss:0.4412
#
# EPOCH[2] - STEP[120]
# Generator_loss:3.3949
# L1_loss:0.2282
# Discriminator_loss:0.6271
#
# EPOCH[2] - STEP[130]
# Generator_loss:3.1894
# L1_loss:0.2077
# Discriminator_loss:0.2320
#
# EPOCH[2] - STEP[140]
# Generator_loss:1.6570
# L1_loss:0.2498
# Discriminator_loss:0.4022
#
# EPOCH[2] - STEP[150]
# Generator_loss:2.2172
# L1_loss:0.2168
# Discriminator_loss:0.5913
#
# EPOCH[2] - STEP[160]
# Generator_loss:1.3476
# L1_loss:0.2842
# Discriminator_loss:0.3710
#
# EPOCH[2] - STEP[170]
# Generator_loss:1.1659
# L1_loss:0.2513
# Discriminator_loss:0.6305
#
# EPOCH[2] - STEP[180]
# Generator_loss:1.0580
# L1_loss:0.2496
# Discriminator_loss:0.6390
#
# EPOCH[2] - STEP[190]
# Generator_loss:0.5291
# L1_loss:0.2485
# Discriminator_loss:1.3424
#
# EPOCH[2] - STEP[200]
# Generator_loss:2.0846
# L1_loss:0.2334
# Discriminator_loss:0.2551
#
# EPOCH[3] - STEP[10]
# Generator_loss:1.1794
# L1_loss:0.2214
# Discriminator_loss:1.2477
#
# EPOCH[3] - STEP[20]
# Generator_loss:1.4526
# L1_loss:0.2027
# Discriminator_loss:0.7746
#
# EPOCH[3] - STEP[30]
# Generator_loss:2.5901
# L1_loss:0.2682
# Discriminator_loss:0.2481
#
# EPOCH[3] - STEP[40]
# Generator_loss:3.7936
# L1_loss:0.2617
# Discriminator_loss:1.1182
#
# EPOCH[3] - STEP[50]
# Generator_loss:1.3926
# L1_loss:0.3308
# Discriminator_loss:0.3385
#
# EPOCH[3] - STEP[60]
# Generator_loss:2.1689
# L1_loss:0.2589
# Discriminator_loss:0.1880
#
# EPOCH[3] - STEP[70]
# Generator_loss:2.2655
# L1_loss:0.1960
# Discriminator_loss:1.0113
#
# EPOCH[3] - STEP[80]
# Generator_loss:3.1559
# L1_loss:0.2834
# Discriminator_loss:0.2368
#
# EPOCH[3] - STEP[90]
# Generator_loss:1.1456
# L1_loss:0.2647
# Discriminator_loss:0.5043
#
# EPOCH[3] - STEP[100]
# Generator_loss:0.7867
# L1_loss:0.2500
# Discriminator_loss:1.3394
#
# EPOCH[3] - STEP[110]
# Generator_loss:1.2294
# L1_loss:0.2138
# Discriminator_loss:1.0744
#
# EPOCH[3] - STEP[120]
# Generator_loss:1.7635
# L1_loss:0.2381
# Discriminator_loss:0.5104
#
# EPOCH[3] - STEP[130]
# Generator_loss:1.5506
# L1_loss:0.2677
# Discriminator_loss:0.3897
#
# EPOCH[3] - STEP[140]
# Generator_loss:1.0864
# L1_loss:0.2464
# Discriminator_loss:0.5375
#
# EPOCH[3] - STEP[150]
# Generator_loss:1.9711
# L1_loss:0.2718
# Discriminator_loss:0.3209
#
# EPOCH[3] - STEP[160]
# Generator_loss:2.1603
# L1_loss:0.2135
# Discriminator_loss:1.3172
# EPOCH[3] - STEP[170]
# Generator_loss:1.0698
# L1_loss:0.2578
# Discriminator_loss:0.8720
#
# EPOCH[3] - STEP[180]
# Generator_loss:2.4194
# L1_loss:0.2604
# Discriminator_loss:0.6159
#
# EPOCH[3] - STEP[190]
# Generator_loss:3.0262
# L1_loss:0.2881
# Discriminator_loss:0.2312
#
# EPOCH[3] - STEP[200]
# Generator_loss:2.4630
# L1_loss:0.2652
# Discriminator_loss:0.8568
#
# EPOCH[4] - STEP[10]
# Generator_loss:1.6060
# L1_loss:0.2388
# Discriminator_loss:0.5183
#
# EPOCH[4] - STEP[20]
# Generator_loss:2.3639
# L1_loss:0.2203
# Discriminator_loss:0.2922
#
# EPOCH[4] - STEP[30]
# Generator_loss:2.0124
# L1_loss:0.2865
# Discriminator_loss:0.2668
#
# EPOCH[4] - STEP[40]
# Generator_loss:1.1396
# L1_loss:0.2617
# Discriminator_loss:2.4974
#
# EPOCH[4] - STEP[50]
# Generator_loss:1.9095
# L1_loss:0.3033
# Discriminator_loss:0.2607
#
# EPOCH[4] - STEP[60]
# Generator_loss:2.4640
# L1_loss:0.2468
# Discriminator_loss:0.1467
#
# EPOCH[4] - STEP[70]
# Generator_loss:0.8782
# L1_loss:0.2545
# Discriminator_loss:0.7849
#
# EPOCH[4] - STEP[80]
# Generator_loss:0.9927
# L1_loss:0.3041
# Discriminator_loss:0.9286
#
# EPOCH[4] - STEP[90]
# Generator_loss:0.8986
# L1_loss:0.2347
# Discriminator_loss:0.9925
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.5930
# L1_loss:0.2389
# Discriminator_loss:1.1412
#
# EPOCH[4] - STEP[110]
# Generator_loss:1.6731
# L1_loss:0.2612
# Discriminator_loss:0.3424
#
# EPOCH[4] - STEP[120]
# Generator_loss:3.0645
# L1_loss:0.3038
# Discriminator_loss:0.1551
#
# EPOCH[4] - STEP[130]
# Generator_loss:4.0303
# L1_loss:0.2225
# Discriminator_loss:0.6576
#
# EPOCH[4] - STEP[140]
# Generator_loss:2.5457
# L1_loss:0.2560
# Discriminator_loss:0.8501
#
# EPOCH[4] - STEP[150]
# Generator_loss:3.5119
# L1_loss:0.2884
# Discriminator_loss:0.4364
#
# EPOCH[4] - STEP[160]
# Generator_loss:1.6553
# L1_loss:0.2401
# Discriminator_loss:0.5307
#
# EPOCH[4] - STEP[170]
# Generator_loss:2.7984
# L1_loss:0.2610
# Discriminator_loss:0.1051
#
# EPOCH[4] - STEP[180]
# Generator_loss:1.0745
# L1_loss:0.2605
# Discriminator_loss:1.0183
#
# EPOCH[4] - STEP[190]
# Generator_loss:1.5258
# L1_loss:0.2486
# Discriminator_loss:1.5195
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.6062
# L1_loss:0.2550
# Discriminator_loss:0.7716
#
# EPOCH[5] - STEP[10]
# Generator_loss:1.0445
# L1_loss:0.2638
# Discriminator_loss:0.6642
#
# EPOCH[5] - STEP[20]
# Generator_loss:2.7353
# L1_loss:0.3104
# Discriminator_loss:0.2401
#
# EPOCH[5] - STEP[30]
# Generator_loss:1.5787
# L1_loss:0.2469
# Discriminator_loss:0.4653
#
# EPOCH[5] - STEP[40]
# Generator_loss:1.6936
# L1_loss:0.2440
# Discriminator_loss:0.3785
#
# EPOCH[5] - STEP[50]
# Generator_loss:1.8030
# L1_loss:0.2591
# Discriminator_loss:0.2852
#
# EPOCH[5] - STEP[60]
# Generator_loss:1.6746
# L1_loss:0.2386
# Discriminator_loss:0.4014
#
# EPOCH[5] - STEP[70]
# Generator_loss:0.6040
# L1_loss:0.2507
# Discriminator_loss:1.8484
#
# EPOCH[5] - STEP[80]
# Generator_loss:2.0654
# L1_loss:0.2895
# Discriminator_loss:0.3535
#
# EPOCH[5] - STEP[90]
# Generator_loss:4.4963
# L1_loss:0.2373
# Discriminator_loss:1.4809
#
# EPOCH[5] - STEP[100]
# Generator_loss:1.6425
# L1_loss:0.2002
# Discriminator_loss:1.1508
#
# EPOCH[5] - STEP[110]
# Generator_loss:1.3835
# L1_loss:0.2846
# Discriminator_loss:0.6977
#
# EPOCH[5] - STEP[120]
# Generator_loss:1.5225
# L1_loss:0.2693
# Discriminator_loss:0.3758
#
# EPOCH[5] - STEP[130]
# Generator_loss:0.3049
# L1_loss:0.2507
# Discriminator_loss:1.9665
#
# EPOCH[5] - STEP[140]
# Generator_loss:0.5734
# L1_loss:0.2622
# Discriminator_loss:0.9926
#
# EPOCH[5] - STEP[150]
# Generator_loss:3.4988
# L1_loss:0.3090
# Discriminator_loss:1.0350
#
# EPOCH[5] - STEP[160]
# Generator_loss:0.5168
# L1_loss:0.2376
# Discriminator_loss:1.1728
#
# EPOCH[5] - STEP[170]
# Generator_loss:2.1542
# L1_loss:0.2288
# Discriminator_loss:0.9307
#
# EPOCH[5] - STEP[180]
# Generator_loss:2.0688
# L1_loss:0.2805
# Discriminator_loss:0.1969
#
# EPOCH[5] - STEP[190]
# Generator_loss:0.9145
# L1_loss:0.2832
# Discriminator_loss:0.6330
#
# EPOCH[5] - STEP[200]
# Generator_loss:0.4924
# L1_loss:0.2783
# Discriminator_loss:1.0981
#
# EPOCH[6] - STEP[10]
# Generator_loss:2.2317
# L1_loss:0.2414
# Discriminator_loss:0.3214
#
# EPOCH[6] - STEP[20]
# Generator_loss:1.9267
# L1_loss:0.2326
# Discriminator_loss:0.5255
#
# EPOCH[6] - STEP[30]
# Generator_loss:1.1041
# L1_loss:0.2181
# Discriminator_loss:1.3230
#
# EPOCH[6] - STEP[40]
# Generator_loss:2.6744
# L1_loss:0.2269
# Discriminator_loss:1.9555
#
# EPOCH[6] - STEP[50]
# Generator_loss:1.3962
# L1_loss:0.2458
# Discriminator_loss:0.6923
#
# EPOCH[6] - STEP[60]
# Generator_loss:2.0690
# L1_loss:0.2429
# Discriminator_loss:0.9221
#
# EPOCH[6] - STEP[70]
# Generator_loss:1.3073
# L1_loss:0.2521
# Discriminator_loss:0.5871
#
# EPOCH[6] - STEP[80]
# Generator_loss:1.6939
# L1_loss:0.2277
# Discriminator_loss:0.6834
#
# EPOCH[6] - STEP[90]
# Generator_loss:0.5647
# L1_loss:0.2499
# Discriminator_loss:0.9596
#
# EPOCH[6] - STEP[100]
# Generator_loss:3.5886
# L1_loss:0.2560
# Discriminator_loss:0.1791
#
# EPOCH[6] - STEP[110]
# Generator_loss:1.8825
# L1_loss:0.2113
# Discriminator_loss:1.2880
#
# EPOCH[6] - STEP[120]
# Generator_loss:1.0260
# L1_loss:0.2677
# Discriminator_loss:0.5731
# EPOCH[6] - STEP[130]
# Generator_loss:0.7575
# L1_loss:0.2642
# Discriminator_loss:0.8895
#
# EPOCH[6] - STEP[140]
# Generator_loss:1.6273
# L1_loss:0.2385
# Discriminator_loss:0.9609
#
# EPOCH[6] - STEP[150]
# Generator_loss:0.6525
# L1_loss:0.2459
# Discriminator_loss:0.8384
#
# EPOCH[6] - STEP[160]
# Generator_loss:1.7627
# L1_loss:0.3045
# Discriminator_loss:0.7526
#
# EPOCH[6] - STEP[170]
# Generator_loss:0.3244
# L1_loss:0.2500
# Discriminator_loss:1.5754
#
# EPOCH[6] - STEP[180]
# Generator_loss:1.6333
# L1_loss:0.2748
# Discriminator_loss:0.3138
#
# EPOCH[6] - STEP[190]
# Generator_loss:0.3993
# L1_loss:0.1924
# Discriminator_loss:1.2982
#
# EPOCH[6] - STEP[200]
# Generator_loss:1.9893
# L1_loss:0.2263
# Discriminator_loss:0.8688
#
# EPOCH[7] - STEP[10]
# Generator_loss:1.8835
# L1_loss:0.2270
# Discriminator_loss:0.9791
#
# EPOCH[7] - STEP[20]
# Generator_loss:2.2867
# L1_loss:0.2382
# Discriminator_loss:0.5807
#
# EPOCH[7] - STEP[30]
# Generator_loss:1.6583
# L1_loss:0.2899
# Discriminator_loss:0.2883
#
# EPOCH[7] - STEP[40]
# Generator_loss:1.4687
# L1_loss:0.2372
# Discriminator_loss:0.3797
#
# EPOCH[7] - STEP[50]
# Generator_loss:2.0474
# L1_loss:0.2345
# Discriminator_loss:0.4289
#
# EPOCH[7] - STEP[60]
# Generator_loss:2.6722
# L1_loss:0.3533
# Discriminator_loss:0.6836
#
# EPOCH[7] - STEP[70]
# Generator_loss:0.8667
# L1_loss:0.2561
# Discriminator_loss:0.8938
#
# EPOCH[7] - STEP[80]
# Generator_loss:2.6899
# L1_loss:0.2585
# Discriminator_loss:0.4248
#
# EPOCH[7] - STEP[90]
# Generator_loss:1.4292
# L1_loss:0.2225
# Discriminator_loss:0.9707
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.5641
# L1_loss:0.2092
# Discriminator_loss:0.4771
#
# EPOCH[7] - STEP[110]
# Generator_loss:0.6009
# L1_loss:0.3144
# Discriminator_loss:1.0159
#
# EPOCH[7] - STEP[120]
# Generator_loss:0.1081
# L1_loss:0.2339
# Discriminator_loss:2.6001
#
# EPOCH[7] - STEP[130]
# Generator_loss:2.0894
# L1_loss:0.2141
# Discriminator_loss:2.3614
#
# EPOCH[7] - STEP[140]
# Generator_loss:1.9550
# L1_loss:0.2432
# Discriminator_loss:1.9801
#
# EPOCH[7] - STEP[150]
# Generator_loss:2.3847
# L1_loss:0.2149
# Discriminator_loss:0.5297
#
# EPOCH[7] - STEP[160]
# Generator_loss:1.3391
# L1_loss:0.2459
# Discriminator_loss:0.3821
#
# EPOCH[7] - STEP[170]
# Generator_loss:2.3912
# L1_loss:0.2708
# Discriminator_loss:0.2827
#
# EPOCH[7] - STEP[180]
# Generator_loss:1.7757
# L1_loss:0.2375
# Discriminator_loss:0.5802
#
# EPOCH[7] - STEP[190]
# Generator_loss:1.7319
# L1_loss:0.2059
# Discriminator_loss:0.6325
#
# EPOCH[7] - STEP[200]
# Generator_loss:0.3613
# L1_loss:0.2959
# Discriminator_loss:1.3327
#
# EPOCH[8] - STEP[10]
# Generator_loss:3.4875
# L1_loss:0.2548
# Discriminator_loss:0.7850
#
# EPOCH[8] - STEP[20]
# Generator_loss:2.4632
# L1_loss:0.2104
# Discriminator_loss:2.0114
#
# EPOCH[8] - STEP[30]
# Generator_loss:4.2127
# L1_loss:0.2220
# Discriminator_loss:1.7878
#
# EPOCH[8] - STEP[40]
# Generator_loss:2.2972
# L1_loss:0.2794
# Discriminator_loss:0.1451
#
# EPOCH[8] - STEP[50]
# Generator_loss:2.4363
# L1_loss:0.2254
# Discriminator_loss:1.5098
#
# EPOCH[8] - STEP[60]
# Generator_loss:1.9105
# L1_loss:0.2754
# Discriminator_loss:0.2962
#
# EPOCH[8] - STEP[70]
# Generator_loss:0.9273
# L1_loss:0.2670
# Discriminator_loss:0.5920
#
# EPOCH[8] - STEP[80]
# Generator_loss:1.5223
# L1_loss:0.2161
# Discriminator_loss:0.7227
#
# EPOCH[8] - STEP[90]
# Generator_loss:0.6611
# L1_loss:0.2664
# Discriminator_loss:0.8171
#
# EPOCH[8] - STEP[100]
# Generator_loss:0.9462
# L1_loss:0.2419
# Discriminator_loss:0.5582
#
# EPOCH[8] - STEP[110]
# Generator_loss:0.2139
# L1_loss:0.2067
# Discriminator_loss:1.9578
#
# EPOCH[8] - STEP[120]
# Generator_loss:2.1387
# L1_loss:0.2515
# Discriminator_loss:0.2468
#
# EPOCH[8] - STEP[130]
# Generator_loss:1.9532
# L1_loss:0.2613
# Discriminator_loss:0.2031
#
# EPOCH[8] - STEP[140]
# Generator_loss:3.6447
# L1_loss:0.3040
# Discriminator_loss:1.3830
#
# EPOCH[8] - STEP[150]
# Generator_loss:2.0104
# L1_loss:0.2635
# Discriminator_loss:0.3264
#
# EPOCH[8] - STEP[160]
# Generator_loss:1.2098
# L1_loss:0.2575
# Discriminator_loss:0.7263
#
# EPOCH[8] - STEP[170]
# Generator_loss:3.1212
# L1_loss:0.2557
# Discriminator_loss:0.4265
#
# EPOCH[8] - STEP[180]
# Generator_loss:2.0685
# L1_loss:0.2564
# Discriminator_loss:0.4408
#
# EPOCH[8] - STEP[190]
# Generator_loss:1.0722
# L1_loss:0.4092
# Discriminator_loss:0.5643
#
# EPOCH[8] - STEP[200]
# Generator_loss:3.8364
# L1_loss:0.2311
# Discriminator_loss:1.3841
#
# EPOCH[9] - STEP[10]
# Generator_loss:1.4445
# L1_loss:0.2855
# Discriminator_loss:0.4442
#
# EPOCH[9] - STEP[20]
# Generator_loss:0.6573
# L1_loss:0.2414
# Discriminator_loss:0.9130
#
# EPOCH[9] - STEP[30]
# Generator_loss:4.6458
# L1_loss:0.2761
# Discriminator_loss:2.0880
#
# EPOCH[9] - STEP[40]
# Generator_loss:1.0917
# L1_loss:0.2490
# Discriminator_loss:0.5140
#
# EPOCH[9] - STEP[50]
# Generator_loss:1.2231
# L1_loss:0.3100
# Discriminator_loss:0.7293
#
# EPOCH[9] - STEP[60]
# Generator_loss:3.5664
# L1_loss:0.2415
# Discriminator_loss:1.8715
#
# EPOCH[9] - STEP[70]
# Generator_loss:1.4843
# L1_loss:0.2537
# Discriminator_loss:0.3882
#
# EPOCH[9] - STEP[80]
# Generator_loss:2.3094
# L1_loss:0.2571
# Discriminator_loss:0.1592
# EPOCH[9] - STEP[90]
# Generator_loss:2.3821
# L1_loss:0.2927
# Discriminator_loss:0.1954
#
# EPOCH[9] - STEP[100]
# Generator_loss:0.2669
# L1_loss:0.2583
# Discriminator_loss:1.5917
#
# EPOCH[9] - STEP[110]
# Generator_loss:1.7320
# L1_loss:0.2410
# Discriminator_loss:0.3780
#
# EPOCH[9] - STEP[120]
# Generator_loss:2.5866
# L1_loss:0.2437
# Discriminator_loss:0.5696
#
# EPOCH[9] - STEP[130]
# Generator_loss:0.4559
# L1_loss:0.2255
# Discriminator_loss:1.1631
#
# EPOCH[9] - STEP[140]
# Generator_loss:1.1072
# L1_loss:0.2259
# Discriminator_loss:1.2202
#
# EPOCH[9] - STEP[150]
# Generator_loss:0.8057
# L1_loss:0.2444
# Discriminator_loss:1.1513
#
# EPOCH[9] - STEP[160]
# Generator_loss:1.4791
# L1_loss:0.2171
# Discriminator_loss:0.4306
#
# EPOCH[9] - STEP[170]
# Generator_loss:2.6174
# L1_loss:0.2815
# Discriminator_loss:0.3125
#
# EPOCH[9] - STEP[180]
# Generator_loss:1.8849
# L1_loss:0.3048
# Discriminator_loss:0.4739
#
# EPOCH[9] - STEP[190]
# Generator_loss:1.4778
# L1_loss:0.2381
# Discriminator_loss:0.5481
#
# EPOCH[9] - STEP[200]
# Generator_loss:2.5494
# L1_loss:0.2118
# Discriminator_loss:1.0524
#
# EPOCH[10] - STEP[10]
# Generator_loss:2.3094
# L1_loss:0.2588
# Discriminator_loss:0.5685
#
# EPOCH[10] - STEP[20]
# Generator_loss:2.7592
# L1_loss:0.1851
# Discriminator_loss:2.6337
#
# EPOCH[10] - STEP[30]
# Generator_loss:3.1063
# L1_loss:0.2316
# Discriminator_loss:0.2737
#
# EPOCH[10] - STEP[40]
# Generator_loss:2.0377
# L1_loss:0.2572
# Discriminator_loss:0.3311
#
# EPOCH[10] - STEP[50]
# Generator_loss:1.4863
# L1_loss:0.2399
# Discriminator_loss:0.5006
#
# EPOCH[10] - STEP[60]
# Generator_loss:1.8267
# L1_loss:0.2541
# Discriminator_loss:1.4620
#
# EPOCH[10] - STEP[70]
# Generator_loss:2.2436
# L1_loss:0.1937
# Discriminator_loss:0.7577
#
# EPOCH[10] - STEP[80]
# Generator_loss:0.7479
# L1_loss:0.2296
# Discriminator_loss:0.7970
#
# EPOCH[10] - STEP[90]
# Generator_loss:1.5880
# L1_loss:0.2188
# Discriminator_loss:0.6677
#
# EPOCH[10] - STEP[100]
# Generator_loss:2.4676
# L1_loss:0.2403
# Discriminator_loss:0.5432
#
# EPOCH[10] - STEP[110]
# Generator_loss:2.7692
# L1_loss:0.2325
# Discriminator_loss:1.9642
#
# EPOCH[10] - STEP[120]
# Generator_loss:4.1797
# L1_loss:0.2226
# Discriminator_loss:0.8176
#
# EPOCH[10] - STEP[130]
# Generator_loss:1.2815
# L1_loss:0.2242
# Discriminator_loss:0.4854
#
# EPOCH[10] - STEP[140]
# Generator_loss:3.3993
# L1_loss:0.2888
# Discriminator_loss:0.4559
#
# EPOCH[10] - STEP[150]
# Generator_loss:2.6240
# L1_loss:0.2283
# Discriminator_loss:0.2826
#
# EPOCH[10] - STEP[160]
# Generator_loss:1.8030
# L1_loss:0.2267
# Discriminator_loss:0.4091
#
# EPOCH[10] - STEP[170]
# Generator_loss:3.3868
# L1_loss:0.2650
# Discriminator_loss:1.4335
#
# EPOCH[10] - STEP[180]
# Generator_loss:3.0809
# L1_loss:0.3481
# Discriminator_loss:0.0852
#
# EPOCH[10] - STEP[190]
# Generator_loss:3.3697
# L1_loss:0.2175
# Discriminator_loss:1.1597
#
# EPOCH[10] - STEP[200]
# Generator_loss:2.8001
# L1_loss:0.2738
# Discriminator_loss:0.1435

# %%
test_ind = 1

f = data_path + os.listdir(data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %% [markdown]
# ## 3. 모델 학습 후, 학습된 Generator를 이용해 테스트합니다. 테스트 데이터는 다운받았던 "val" 폴더 내 이미지를 사용해주세요.

# %%
test_ind = 1

f = val_data_path + os.listdir(val_data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %% [markdown]
# ## 4. 1개 이상의 이미지에 대해 테스트 과정을 거친 후 그 결과를 스케치, 생성된 사진, 실제 사진 순서로 나란히 시각화 해 주세요.

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(denormalize(colored))
plt.subplot(1,3,3); plt.imshow(pred[0])
